# %%
# !pip install torch torchvision
# !pip install matplotlib
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 88.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 64.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 58.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models
from torchvision.datasets import ImageFolder
import matplotlib.pyplot as plt
import numpy as np
import os
from sklearn.model_selection import train_test_split
import zipfile

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
    -O /content/cats_and_dogs_filtered.zip
# Out:
# --2025-02-03 10:48:42--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.203.207, 142.250.98.207, 142.251.107.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.203.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/content/cats_and_dogs_filtered.zip’
#
# /content/cats_and_d 100%[===================>]  65.43M   200MB/s    in 0.3s
#
# 2025-02-03 10:48:43 (200 MB/s) - ‘/content/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
import zipfile
with zipfile.ZipFile('/content/cats_and_dogs_filtered.zip', 'r') as zip_ref:

    zip_ref.extractall('/content/')

# %%
zip_ref=zipfile.ZipFile('/content/cats_and_dogs_filtered.zip','r')
zip_ref.extractall('./content')
zip_ref.close()
# Define transformations
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Load dataset
cats_vs_dogs_dataset = ImageFolder(root='/content/cats_and_dogs_filtered', transform=transform)

# Split dataset into training and validation sets
train_size = int(0.8 * len(cats_vs_dogs_dataset))
val_size = len(cats_vs_dogs_dataset) - train_size
train_dataset, val_dataset = random_split(cats_vs_dogs_dataset, [train_size, val_size])

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
# Define transformations
transform_cifar = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Load dataset
cifar10_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_cifar)

# Split dataset into training and validation sets
train_size_cifar = int(0.8 * len(cifar10_dataset))
val_size_cifar = len(cifar10_dataset) - train_size_cifar
train_dataset_cifar, val_dataset_cifar = random_split(cifar10_dataset, [train_size_cifar, val_size_cifar])

# Create data loaders
train_loader_cifar = DataLoader(train_dataset_cifar, batch_size=32, shuffle=True)
val_loader_cifar = DataLoader(val_dataset_cifar, batch_size=32, shuffle=False)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:02<00:00, 77.5MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data

# %%
class CNN(nn.Module):
    def __init__(self, activation_fn, weight_init):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(64 * 16 * 16, 512)
        self.fc2 = nn.Linear(512, 2)  # 2 classes for Cats vs. Dogs
        self.dropout = nn.Dropout(0.5)
        self.batch_norm1 = nn.BatchNorm2d(32)
        self.batch_norm2 = nn.BatchNorm2d(64)

        # Activation function
        if activation_fn == 'relu':
            self.activation = F.relu
        elif activation_fn == 'tanh':
            self.activation = torch.tanh
        elif activation_fn == 'leaky_relu':
            self.activation = F.leaky_relu

        # Weight initialization
        if weight_init == 'xavier':
            nn.init.xavier_uniform_(self.conv1.weight)
            nn.init.xavier_uniform_(self.conv2.weight)
            nn.init.xavier_uniform_(self.fc1.weight)
            nn.init.xavier_uniform_(self.fc2.weight)
        elif weight_init == 'kaiming':
            nn.init.kaiming_uniform_(self.conv1.weight, mode='fan_in', nonlinearity='relu')
            nn.init.kaiming_uniform_(self.conv2.weight, mode='fan_in', nonlinearity='relu')
            nn.init.kaiming_uniform_(self.fc1.weight, mode='fan_in', nonlinearity='relu')
            nn.init.kaiming_uniform_(self.fc2.weight, mode='fan_in', nonlinearity='relu')
        elif weight_init == 'random':
            nn.init.normal_(self.conv1.weight, mean=0, std=0.01)
            nn.init.normal_(self.conv2.weight, mean=0, std=0.01)
            nn.init.normal_(self.fc1.weight, mean=0, std=0.01)
            nn.init.normal_(self.fc2.weight, mean=0, std=0.01)

    def forward(self, x):
        x = self.pool(self.activation(self.batch_norm1(self.conv1(x))))
        x = self.pool(self.activation(self.batch_norm2(self.conv2(x))))
        x = x.view(-1, 64 * 16 * 16)
        x = self.dropout(self.activation(self.fc1(x)))
        x = self.fc2(x)
        return x

# %%
def train_model(model, train_loader, val_loader, optimizer, criterion, num_epochs=10):
    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for inputs, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_loss = running_loss / len(train_loader)
        train_accuracy = 100 * correct / total
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)

        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():
            for inputs, labels in val_loader:
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_loss = val_loss / len(val_loader)
        val_accuracy = 100 * correct / total
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)

        print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%')

    return train_losses, val_losses, train_accuracies, val_accuracies

# %%
activation_fns = ['relu', 'tanh', 'leaky_relu']
weight_inits = ['xavier', 'kaiming', 'random']
optimizers_list = ['sgd', 'adam', 'rmsprop']

results = {}

for activation_fn in activation_fns:
    for weight_init in weight_inits:
        for optimizer_name in optimizers_list:
            print(f'Training with Activation: {activation_fn}, Weight Init: {weight_init}, Optimizer: {optimizer_name}')

            # Initialize model
            model = CNN(activation_fn=activation_fn, weight_init=weight_init)

            # Define optimizer
            if optimizer_name == 'sgd':
                optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
            elif optimizer_name == 'adam':
                optimizer = optim.Adam(model.parameters(), lr=0.001)
            elif optimizer_name == 'rmsprop':
                optimizer = optim.RMSprop(model.parameters(), lr=0.001)

            # Define loss function
            criterion = nn.CrossEntropyLoss()

            # Train model
            train_losses, val_losses, train_accuracies, val_accuracies = train_model(model, train_loader, val_loader, optimizer, criterion, num_epochs=10)

            # Save results
            results[(activation_fn, weight_init, optimizer_name)] = {
                'train_losses': train_losses,
                'val_losses': val_losses,
                'train_accuracies': train_accuracies,
                'val_accuracies': val_accuracies
            }
# Out:
# Training with Activation: relu, Weight Init: xavier, Optimizer: sgd
# Epoch 1/10, Train Loss: 0.8398, Train Acc: 61.08%, Val Loss: 0.6448, Val Acc: 65.50%
# Epoch 2/10, Train Loss: 0.6386, Train Acc: 65.79%, Val Loss: 0.6646, Val Acc: 66.33%
# Epoch 3/10, Train Loss: 0.6123, Train Acc: 67.33%, Val Loss: 0.6727, Val Acc: 65.67%
# Epoch 4/10, Train Loss: 0.6007, Train Acc: 67.92%, Val Loss: 0.6761, Val Acc: 64.83%
# Epoch 5/10, Train Loss: 0.5801, Train Acc: 69.71%, Val Loss: 0.6956, Val Acc: 63.17%
# Epoch 6/10, Train Loss: 0.5646, Train Acc: 71.54%, Val Loss: 0.6793, Val Acc: 63.50%
# Epoch 7/10, Train Loss: 0.5255, Train Acc: 73.46%, Val Loss: 0.6828, Val Acc: 61.67%
# Epoch 8/10, Train Loss: 0.4897, Train Acc: 76.50%, Val Loss: 0.6934, Val Acc: 62.50%
# Epoch 9/10, Train Loss: 0.4580, Train Acc: 78.29%, Val Loss: 0.7144, Val Acc: 61.50%
# Epoch 10/10, Train Loss: 0.4345, Train Acc: 80.00%, Val Loss: 0.7363, Val Acc: 64.33%
# Training with Activation: relu, Weight Init: xavier, Optimizer: adam
# Epoch 1/10, Train Loss: 3.9426, Train Acc: 58.79%, Val Loss: 0.6605, Val Acc: 66.50%
# Epoch 2/10, Train Loss: 0.6576, Train Acc: 65.25%, Val Loss: 0.6497, Val Acc: 66.33%
# Epoch 3/10, Train Loss: 0.6525, Train Acc: 66.17%, Val Loss: 0.6439, Val Acc: 66.17%
# Epoch 4/10, Train Loss: 0.6517, Train Acc: 66.62%, Val Loss: 0.6451, Val Acc: 66.33%
# Epoch 5/10, Train Loss: 0.6564, Train Acc: 66.25%, Val Loss: 0.6451, Val Acc: 66.33%
# Epoch 6/10, Train Loss: 0.6444, Train Acc: 66.58%, Val Loss: 0.6417, Val Acc: 66.33%
# Epoch 7/10, Train Loss: 0.6371, Train Acc: 66.83%, Val Loss: 0.6522, Val Acc: 66.33%
# Epoch 8/10, Train Loss: 0.6366, Train Acc: 66.83%, Val Loss: 0.6447, Val Acc: 66.33%
# Epoch 9/10, Train Loss: 0.6397, Train Acc: 66.75%, Val Loss: 0.6477, Val Acc: 66.33%
# Epoch 10/10, Train Loss: 0.6358, Train Acc: 66.62%, Val Loss: 0.6470, Val Acc: 66.33%
# Training with Activation: relu, Weight Init: xavier, Optimizer: rmsprop
# Epoch 1/10, Train Loss: 19.5242, Train Acc: 55.96%, Val Loss: 0.9725, Val Acc: 66.67%
# Epoch 2/10, Train Loss: 0.7267, Train Acc: 62.25%, Val Loss: 0.6593, Val Acc: 65.67%
# Epoch 3/10, Train Loss: 0.6445, Train Acc: 66.96%, Val Loss: 0.6622, Val Acc: 66.00%
# Epoch 4/10, Train Loss: 0.6439, Train Acc: 66.62%, Val Loss: 0.6614, Val Acc: 66.17%
# Epoch 5/10, Train Loss: 0.6552, Train Acc: 65.62%, Val Loss: 0.6546, Val Acc: 65.83%
# Epoch 6/10, Train Loss: 0.6391, Train Acc: 67.12%, Val Loss: 0.6987, Val Acc: 60.83%
# Epoch 7/10, Train Loss: 0.6412, Train Acc: 66.12%, Val Loss: 0.6504, Val Acc: 66.33%
# Epoch 8/10, Train Loss: 0.6408, Train Acc: 66.38%, Val Loss: 0.7722, Val Acc: 66.33%
# Epoch 9/10, Train Loss: 0.6463, Train Acc: 66.62%, Val Loss: 0.6814, Val Acc: 66.33%
# Epoch 10/10, Train Loss: 0.6691, Train Acc: 66.08%, Val Loss: 0.6523, Val Acc: 66.33%
# Training with Activation: relu, Weight Init: kaiming, Optimizer: sgd
# Epoch 1/10, Train Loss: 0.9826, Train Acc: 57.96%, Val Loss: 0.6605, Val Acc: 66.33%
# Epoch 2/10, Train Loss: 0.6373, Train Acc: 66.08%, Val Loss: 0.6506, Val Acc: 65.83%
# Epoch 3/10, Train Loss: 0.6235, Train Acc: 67.21%, Val Loss: 0.6469, Val Acc: 66.33%
# Epoch 4/10, Train Loss: 0.6061, Train Acc: 67.71%, Val Loss: 0.6570, Val Acc: 66.17%
# Epoch 5/10, Train Loss: 0.5898, Train Acc: 69.21%, Val Loss: 0.6656, Val Acc: 66.17%
# Epoch 6/10, Train Loss: 0.5726, Train Acc: 70.83%, Val Loss: 0.6829, Val Acc: 61.67%
# Epoch 7/10, Train Loss: 0.5513, Train Acc: 71.58%, Val Loss: 0.6775, Val Acc: 65.67%
# Epoch 8/10, Train Loss: 0.5252, Train Acc: 73.96%, Val Loss: 0.7038, Val Acc: 66.00%
# Epoch 9/10, Train Loss: 0.4998, Train Acc: 75.17%, Val Loss: 0.6950, Val Acc: 64.33%
# Epoch 10/10, Train Loss: 0.4706, Train Acc: 77.88%, Val Loss: 0.7011, Val Acc: 62.00%
# Training with Activation: relu, Weight Init: kaiming, Optimizer: adam
# Epoch 1/10, Train Loss: 3.9089, Train Acc: 58.25%, Val Loss: 0.6505, Val Acc: 66.33%
# Epoch 2/10, Train Loss: 0.6474, Train Acc: 66.38%, Val Loss: 0.6460, Val Acc: 66.33%
# Epoch 3/10, Train Loss: 0.6496, Train Acc: 66.58%, Val Loss: 0.6504, Val Acc: 66.33%
# Epoch 4/10, Train Loss: 0.6426, Train Acc: 66.75%, Val Loss: 0.6562, Val Acc: 66.33%
# Epoch 5/10, Train Loss: 0.6376, Train Acc: 66.75%, Val Loss: 0.6504, Val Acc: 66.33%
# Epoch 6/10, Train Loss: 0.6376, Train Acc: 66.79%, Val Loss: 0.6421, Val Acc: 66.33%
# Epoch 7/10, Train Loss: 0.6414, Train Acc: 66.54%, Val Loss: 0.6593, Val Acc: 66.33%
# Epoch 8/10, Train Loss: 0.6500, Train Acc: 66.75%, Val Loss: 0.6481, Val Acc: 66.33%
# Epoch 9/10, Train Loss: 0.6434, Train Acc: 66.67%, Val Loss: 0.6487, Val Acc: 66.33%
# Epoch 10/10, Train Loss: 0.6393, Train Acc: 66.75%, Val Loss: 0.6520, Val Acc: 66.33%
# Training with Activation: relu, Weight Init: kaiming, Optimizer: rmsprop
# Epoch 1/10, Train Loss: 19.7013, Train Acc: 57.33%, Val Loss: 0.6851, Val Acc: 62.67%
# Epoch 2/10, Train Loss: 0.6633, Train Acc: 64.71%, Val Loss: 0.6560, Val Acc: 66.17%
# Epoch 3/10, Train Loss: 0.6469, Train Acc: 65.92%, Val Loss: 0.6493, Val Acc: 66.33%
# Epoch 4/10, Train Loss: 0.6559, Train Acc: 66.17%, Val Loss: 0.6798, Val Acc: 61.67%
# Epoch 5/10, Train Loss: 0.6480, Train Acc: 66.42%, Val Loss: 0.6527, Val Acc: 66.33%
# Epoch 6/10, Train Loss: 0.6888, Train Acc: 66.21%, Val Loss: 0.6497, Val Acc: 66.33%
# Epoch 7/10, Train Loss: 0.6883, Train Acc: 66.42%, Val Loss: 0.6481, Val Acc: 66.33%
# Epoch 8/10, Train Loss: 0.6520, Train Acc: 66.29%, Val Loss: 0.6439, Val Acc: 66.33%
# Epoch 9/10, Train Loss: 0.6527, Train Acc: 66.58%, Val Loss: 0.6498, Val Acc: 66.33%
# Epoch 10/10, Train Loss: 0.6628, Train Acc: 66.46%, Val Loss: 0.6507, Val Acc: 66.33%
# Training with Activation: relu, Weight Init: random, Optimizer: sgd
# Epoch 1/10, Train Loss: 0.6585, Train Acc: 63.62%, Val Loss: 0.6489, Val Acc: 66.33%
# Epoch 2/10, Train Loss: 0.6429, Train Acc: 66.62%, Val Loss: 0.6546, Val Acc: 66.33%
# Epoch 3/10, Train Loss: 0.6347, Train Acc: 66.54%, Val Loss: 0.6568, Val Acc: 66.33%
# Epoch 4/10, Train Loss: 0.6221, Train Acc: 66.92%, Val Loss: 0.6669, Val Acc: 66.33%
# Epoch 5/10, Train Loss: 0.6257, Train Acc: 67.25%, Val Loss: 0.6700, Val Acc: 61.17%
# Epoch 6/10, Train Loss: 0.6175, Train Acc: 67.33%, Val Loss: 0.6536, Val Acc: 66.83%
# Epoch 7/10, Train Loss: 0.5956, Train Acc: 68.62%, Val Loss: 0.6923, Val Acc: 64.83%
# Epoch 8/10, Train Loss: 0.5934, Train Acc: 69.46%, Val Loss: 0.6758, Val Acc: 65.67%
# Epoch 9/10, Train Loss: 0.5668, Train Acc: 70.38%, Val Loss: 0.6722, Val Acc: 64.33%
# Epoch 10/10, Train Loss: 0.5528, Train Acc: 71.88%, Val Loss: 0.6843, Val Acc: 63.17%
# Training with Activation: relu, Weight Init: random, Optimizer: adam
# Epoch 1/10, Train Loss: 0.9308, Train Acc: 62.75%, Val Loss: 0.6549, Val Acc: 66.33%
# Epoch 2/10, Train Loss: 0.6484, Train Acc: 66.12%, Val Loss: 0.6519, Val Acc: 66.33%
# Epoch 3/10, Train Loss: 0.6455, Train Acc: 66.75%, Val Loss: 0.6415, Val Acc: 66.33%
# Epoch 4/10, Train Loss: 0.6416, Train Acc: 66.79%, Val Loss: 0.6495, Val Acc: 66.33%
# Epoch 5/10, Train Loss: 0.6378, Train Acc: 66.75%, Val Loss: 0.6697, Val Acc: 66.33%
# Epoch 6/10, Train Loss: 0.6430, Train Acc: 66.75%, Val Loss: 0.6513, Val Acc: 66.33%
# Epoch 7/10, Train Loss: 0.6466, Train Acc: 66.67%, Val Loss: 0.6487, Val Acc: 66.33%
# Epoch 8/10, Train Loss: 0.6406, Train Acc: 66.75%, Val Loss: 0.6473, Val Acc: 66.33%
# Epoch 9/10, Train Loss: 0.6400, Train Acc: 66.75%, Val Loss: 0.6526, Val Acc: 66.33%
# Epoch 10/10, Train Loss: 0.6412, Train Acc: 66.75%, Val Loss: 0.6469, Val Acc: 66.33%
# Training with Activation: relu, Weight Init: random, Optimizer: rmsprop
# Epoch 1/10, Train Loss: 6.6671, Train Acc: 59.33%, Val Loss: 0.6404, Val Acc: 66.33%
# Epoch 2/10, Train Loss: 0.6455, Train Acc: 66.04%, Val Loss: 0.6442, Val Acc: 66.33%
# Epoch 3/10, Train Loss: 0.6468, Train Acc: 66.71%, Val Loss: 0.6711, Val Acc: 60.17%
# Epoch 4/10, Train Loss: 0.6534, Train Acc: 65.00%, Val Loss: 0.6491, Val Acc: 66.33%
# Epoch 5/10, Train Loss: 0.6527, Train Acc: 66.17%, Val Loss: 0.6587, Val Acc: 66.33%
# Epoch 6/10, Train Loss: 0.6439, Train Acc: 66.50%, Val Loss: 0.6490, Val Acc: 66.17%
# Epoch 7/10, Train Loss: 0.6478, Train Acc: 66.54%, Val Loss: 0.6577, Val Acc: 66.33%
# Epoch 8/10, Train Loss: 0.6624, Train Acc: 65.92%, Val Loss: 0.6408, Val Acc: 66.33%
# Epoch 9/10, Train Loss: 0.6429, Train Acc: 66.62%, Val Loss: 0.6569, Val Acc: 66.17%
# Epoch 10/10, Train Loss: 0.6433, Train Acc: 66.71%, Val Loss: 0.6502, Val Acc: 65.83%
# Training with Activation: tanh, Weight Init: xavier, Optimizer: sgd
# Epoch 1/10, Train Loss: 0.9547, Train Acc: 56.75%, Val Loss: 0.8206, Val Acc: 53.50%
# Epoch 2/10, Train Loss: 0.7735, Train Acc: 63.17%, Val Loss: 0.7367, Val Acc: 61.17%
# Epoch 3/10, Train Loss: 0.6789, Train Acc: 64.71%, Val Loss: 0.6910, Val Acc: 62.50%
# Epoch 4/10, Train Loss: 0.5910, Train Acc: 70.21%, Val Loss: 0.6851, Val Acc: 63.17%
# Epoch 5/10, Train Loss: 0.5446, Train Acc: 72.92%, Val Loss: 0.6888, Val Acc: 63.33%
# Epoch 6/10, Train Loss: 0.5186, Train Acc: 73.04%, Val Loss: 0.7328, Val Acc: 61.33%
# Epoch 7/10, Train Loss: 0.4922, Train Acc: 75.75%, Val Loss: 0.7034, Val Acc: 63.17%
# Epoch 8/10, Train Loss: 0.4369, Train Acc: 79.38%, Val Loss: 0.7322, Val Acc: 60.50%
# Epoch 9/10, Train Loss: 0.4244, Train Acc: 80.54%, Val Loss: 0.7712, Val Acc: 64.33%
# Epoch 10/10, Train Loss: 0.4338, Train Acc: 80.54%, Val Loss: 0.8004, Val Acc: 59.67%
# Training with Activation: tanh, Weight Init: xavier, Optimizer: adam
# Epoch 1/10, Train Loss: 1.1380, Train Acc: 57.33%, Val Loss: 0.6835, Val Acc: 66.17%
# Epoch 2/10, Train Loss: 0.8585, Train Acc: 57.54%, Val Loss: 0.6681, Val Acc: 66.17%
# Epoch 3/10, Train Loss: 0.8190, Train Acc: 58.00%, Val Loss: 0.6625, Val Acc: 66.67%
# Epoch 4/10, Train Loss: 0.7732, Train Acc: 60.29%, Val Loss: 0.6478, Val Acc: 66.33%
# Epoch 5/10, Train Loss: 0.7808, Train Acc: 58.79%, Val Loss: 0.6449, Val Acc: 66.33%
# Epoch 6/10, Train Loss: 0.7228, Train Acc: 60.79%, Val Loss: 0.6517, Val Acc: 66.50%
# Epoch 7/10, Train Loss: 0.7183, Train Acc: 60.46%, Val Loss: 0.6901, Val Acc: 56.33%
# Epoch 8/10, Train Loss: 0.6884, Train Acc: 62.46%, Val Loss: 0.6557, Val Acc: 64.67%
# Epoch 9/10, Train Loss: 0.6726, Train Acc: 63.83%, Val Loss: 0.6679, Val Acc: 66.33%
# Epoch 10/10, Train Loss: 0.6622, Train Acc: 64.21%, Val Loss: 0.6614, Val Acc: 66.33%
# Training with Activation: tanh, Weight Init: xavier, Optimizer: rmsprop
# Epoch 1/10, Train Loss: 1.1336, Train Acc: 57.58%, Val Loss: 0.7371, Val Acc: 66.83%
# Epoch 2/10, Train Loss: 0.8364, Train Acc: 59.21%, Val Loss: 0.6987, Val Acc: 64.17%
# Epoch 3/10, Train Loss: 0.7541, Train Acc: 60.33%, Val Loss: 0.7087, Val Acc: 60.17%
# Epoch 4/10, Train Loss: 0.7149, Train Acc: 62.50%, Val Loss: 0.6583, Val Acc: 66.50%
# Epoch 5/10, Train Loss: 0.6839, Train Acc: 62.96%, Val Loss: 0.6698, Val Acc: 59.50%
# Epoch 6/10, Train Loss: 0.6814, Train Acc: 62.58%, Val Loss: 0.6728, Val Acc: 60.67%
# Epoch 7/10, Train Loss: 0.6783, Train Acc: 62.83%, Val Loss: 0.6540, Val Acc: 64.33%
# Epoch 8/10, Train Loss: 0.6549, Train Acc: 63.96%, Val Loss: 0.6426, Val Acc: 65.67%
# Epoch 9/10, Train Loss: 0.6615, Train Acc: 63.54%, Val Loss: 0.6473, Val Acc: 65.33%
# Epoch 10/10, Train Loss: 0.6515, Train Acc: 63.67%, Val Loss: 0.6413, Val Acc: 65.00%
# Training with Activation: tanh, Weight Init: kaiming, Optimizer: sgd
# Epoch 1/10, Train Loss: 0.9786, Train Acc: 57.12%, Val Loss: 0.9695, Val Acc: 50.17%
# Epoch 2/10, Train Loss: 0.7500, Train Acc: 63.33%, Val Loss: 0.7333, Val Acc: 59.50%
# Epoch 3/10, Train Loss: 0.6442, Train Acc: 69.29%, Val Loss: 0.6994, Val Acc: 59.33%
# Epoch 4/10, Train Loss: 0.5814, Train Acc: 71.67%, Val Loss: 0.6931, Val Acc: 61.50%
# Epoch 5/10, Train Loss: 0.4953, Train Acc: 75.67%, Val Loss: 0.7267, Val Acc: 64.17%
# Epoch 6/10, Train Loss: 0.4733, Train Acc: 77.21%, Val Loss: 0.7355, Val Acc: 60.33%
# Epoch 7/10, Train Loss: 0.4691, Train Acc: 77.38%, Val Loss: 0.7385, Val Acc: 59.83%
# Epoch 8/10, Train Loss: 0.4451, Train Acc: 78.83%, Val Loss: 0.7398, Val Acc: 60.83%
# Epoch 9/10, Train Loss: 0.3751, Train Acc: 83.33%, Val Loss: 0.7584, Val Acc: 59.33%
# Epoch 10/10, Train Loss: 0.3626, Train Acc: 84.71%, Val Loss: 0.7985, Val Acc: 54.17%
# Training with Activation: tanh, Weight Init: kaiming, Optimizer: adam
# Epoch 1/10, Train Loss: 1.1448, Train Acc: 57.42%, Val Loss: 0.6971, Val Acc: 66.00%
# Epoch 2/10, Train Loss: 0.8788, Train Acc: 56.96%, Val Loss: 0.7289, Val Acc: 65.83%
# Epoch 3/10, Train Loss: 0.8105, Train Acc: 59.67%, Val Loss: 0.6670, Val Acc: 66.17%
# Epoch 4/10, Train Loss: 0.7662, Train Acc: 59.83%, Val Loss: 0.6774, Val Acc: 66.33%
# Epoch 5/10, Train Loss: 0.7104, Train Acc: 62.79%, Val Loss: 0.6547, Val Acc: 65.00%
# Epoch 6/10, Train Loss: 0.6897, Train Acc: 63.38%, Val Loss: 0.6524, Val Acc: 65.33%
# Epoch 7/10, Train Loss: 0.6847, Train Acc: 62.75%, Val Loss: 0.6469, Val Acc: 66.50%
# Epoch 8/10, Train Loss: 0.6549, Train Acc: 64.58%, Val Loss: 0.6658, Val Acc: 65.33%
# Epoch 9/10, Train Loss: 0.6550, Train Acc: 64.38%, Val Loss: 0.6596, Val Acc: 63.17%
# Epoch 10/10, Train Loss: 0.6378, Train Acc: 64.92%, Val Loss: 0.6517, Val Acc: 66.17%
# Training with Activation: tanh, Weight Init: kaiming, Optimizer: rmsprop
# Epoch 1/10, Train Loss: 1.1008, Train Acc: 58.62%, Val Loss: 0.7239, Val Acc: 56.67%
# Epoch 2/10, Train Loss: 0.7887, Train Acc: 59.29%, Val Loss: 0.6914, Val Acc: 61.17%
# Epoch 3/10, Train Loss: 0.7367, Train Acc: 60.21%, Val Loss: 0.6786, Val Acc: 66.33%
# Epoch 4/10, Train Loss: 0.7031, Train Acc: 61.83%, Val Loss: 0.6721, Val Acc: 65.50%
# Epoch 5/10, Train Loss: 0.6877, Train Acc: 61.12%, Val Loss: 0.6776, Val Acc: 63.67%
# Epoch 6/10, Train Loss: 0.6660, Train Acc: 63.38%, Val Loss: 0.6636, Val Acc: 64.67%
# Epoch 7/10, Train Loss: 0.6682, Train Acc: 63.00%, Val Loss: 0.6542, Val Acc: 64.67%
# Epoch 8/10, Train Loss: 0.6553, Train Acc: 64.33%, Val Loss: 0.6837, Val Acc: 57.50%
# Epoch 9/10, Train Loss: 0.6535, Train Acc: 64.17%, Val Loss: 0.6506, Val Acc: 65.83%
# Epoch 10/10, Train Loss: 0.6561, Train Acc: 64.46%, Val Loss: 0.6497, Val Acc: 64.50%
# Training with Activation: tanh, Weight Init: random, Optimizer: sgd
# Epoch 1/10, Train Loss: 0.6559, Train Acc: 63.75%, Val Loss: 0.6399, Val Acc: 66.50%
# Epoch 2/10, Train Loss: 0.6433, Train Acc: 65.50%, Val Loss: 0.6541, Val Acc: 64.33%
# Epoch 3/10, Train Loss: 0.6334, Train Acc: 65.42%, Val Loss: 0.6465, Val Acc: 65.33%
# Epoch 4/10, Train Loss: 0.6250, Train Acc: 65.83%, Val Loss: 0.6675, Val Acc: 61.50%
# Epoch 5/10, Train Loss: 0.6298, Train Acc: 66.42%, Val Loss: 0.6581, Val Acc: 64.83%
# Epoch 6/10, Train Loss: 0.6177, Train Acc: 67.33%, Val Loss: 0.6539, Val Acc: 66.00%
# Epoch 7/10, Train Loss: 0.6054, Train Acc: 68.00%, Val Loss: 0.6676, Val Acc: 63.33%
# Epoch 8/10, Train Loss: 0.5945, Train Acc: 69.25%, Val Loss: 0.6687, Val Acc: 63.67%
# Epoch 9/10, Train Loss: 0.5765, Train Acc: 70.12%, Val Loss: 0.6805, Val Acc: 62.33%
# Epoch 10/10, Train Loss: 0.5699, Train Acc: 70.33%, Val Loss: 0.6781, Val Acc: 63.00%
# Training with Activation: tanh, Weight Init: random, Optimizer: adam
# Epoch 1/10, Train Loss: 0.6700, Train Acc: 63.42%, Val Loss: 0.6591, Val Acc: 64.17%
# Epoch 2/10, Train Loss: 0.6685, Train Acc: 62.00%, Val Loss: 0.6576, Val Acc: 62.67%
# Epoch 3/10, Train Loss: 0.6554, Train Acc: 63.50%, Val Loss: 0.6608, Val Acc: 65.50%
# Epoch 4/10, Train Loss: 0.6646, Train Acc: 63.17%, Val Loss: 0.6414, Val Acc: 66.00%
# Epoch 5/10, Train Loss: 0.6609, Train Acc: 64.04%, Val Loss: 0.6518, Val Acc: 66.67%
# Epoch 6/10, Train Loss: 0.6590, Train Acc: 63.75%, Val Loss: 0.6524, Val Acc: 65.67%
# Epoch 7/10, Train Loss: 0.6497, Train Acc: 65.33%, Val Loss: 0.6458, Val Acc: 65.67%
# Epoch 8/10, Train Loss: 0.6720, Train Acc: 63.21%, Val Loss: 0.6520, Val Acc: 66.17%
# Epoch 9/10, Train Loss: 0.6566, Train Acc: 63.08%, Val Loss: 0.6513, Val Acc: 65.00%
# Epoch 10/10, Train Loss: 0.6617, Train Acc: 64.08%, Val Loss: 0.6492, Val Acc: 65.67%
# Training with Activation: tanh, Weight Init: random, Optimizer: rmsprop
# Epoch 1/10, Train Loss: 0.7488, Train Acc: 59.62%, Val Loss: 0.6771, Val Acc: 60.83%
# Epoch 2/10, Train Loss: 0.6750, Train Acc: 63.12%, Val Loss: 0.6489, Val Acc: 65.50%
# Epoch 3/10, Train Loss: 0.6679, Train Acc: 62.33%, Val Loss: 0.6518, Val Acc: 64.67%
# Epoch 4/10, Train Loss: 0.6744, Train Acc: 62.00%, Val Loss: 0.6831, Val Acc: 63.33%
# Epoch 5/10, Train Loss: 0.6550, Train Acc: 62.21%, Val Loss: 0.6896, Val Acc: 63.67%
# Epoch 6/10, Train Loss: 0.6622, Train Acc: 63.62%, Val Loss: 0.6552, Val Acc: 65.33%
# Epoch 7/10, Train Loss: 0.6535, Train Acc: 64.83%, Val Loss: 0.6475, Val Acc: 66.50%
# Epoch 8/10, Train Loss: 0.6566, Train Acc: 63.88%, Val Loss: 0.6568, Val Acc: 66.33%
# Epoch 9/10, Train Loss: 0.6484, Train Acc: 64.71%, Val Loss: 0.6571, Val Acc: 64.17%
# Epoch 10/10, Train Loss: 0.6506, Train Acc: 65.00%, Val Loss: 0.6572, Val Acc: 64.33%
# Training with Activation: leaky_relu, Weight Init: xavier, Optimizer: sgd
# Epoch 1/10, Train Loss: 0.9064, Train Acc: 58.71%, Val Loss: 0.6521, Val Acc: 65.67%
# Epoch 2/10, Train Loss: 0.6320, Train Acc: 66.50%, Val Loss: 0.6544, Val Acc: 65.17%
# Epoch 3/10, Train Loss: 0.6179, Train Acc: 67.50%, Val Loss: 0.6541, Val Acc: 66.33%
# Epoch 4/10, Train Loss: 0.6056, Train Acc: 67.54%, Val Loss: 0.6632, Val Acc: 65.67%
# Epoch 5/10, Train Loss: 0.5833, Train Acc: 69.83%, Val Loss: 0.6768, Val Acc: 60.33%
# Epoch 6/10, Train Loss: 0.5670, Train Acc: 70.54%, Val Loss: 0.6813, Val Acc: 62.67%
# Epoch 7/10, Train Loss: 0.5584, Train Acc: 71.46%, Val Loss: 0.7098, Val Acc: 66.00%
# Epoch 8/10, Train Loss: 0.5174, Train Acc: 74.29%, Val Loss: 0.6931, Val Acc: 66.00%
# Epoch 9/10, Train Loss: 0.4949, Train Acc: 76.58%, Val Loss: 0.7144, Val Acc: 59.33%
# Epoch 10/10, Train Loss: 0.4677, Train Acc: 77.96%, Val Loss: 0.7288, Val Acc: 62.83%
# Training with Activation: leaky_relu, Weight Init: xavier, Optimizer: adam
# Epoch 1/10, Train Loss: 3.7640, Train Acc: 55.12%, Val Loss: 0.6449, Val Acc: 66.17%
# Epoch 2/10, Train Loss: 0.6771, Train Acc: 62.58%, Val Loss: 0.6455, Val Acc: 66.50%
# Epoch 3/10, Train Loss: 0.6726, Train Acc: 63.62%, Val Loss: 0.6534, Val Acc: 66.33%
# Epoch 4/10, Train Loss: 0.6595, Train Acc: 65.00%, Val Loss: 0.6603, Val Acc: 66.33%
# Epoch 5/10, Train Loss: 0.6753, Train Acc: 64.00%, Val Loss: 0.6459, Val Acc: 66.17%
# Epoch 6/10, Train Loss: 0.6591, Train Acc: 64.46%, Val Loss: 0.6449, Val Acc: 66.33%
# Epoch 7/10, Train Loss: 0.6586, Train Acc: 64.79%, Val Loss: 0.6526, Val Acc: 66.33%
# Epoch 8/10, Train Loss: 0.6460, Train Acc: 64.71%, Val Loss: 0.6912, Val Acc: 66.33%
# Epoch 9/10, Train Loss: 0.6569, Train Acc: 64.17%, Val Loss: 0.6699, Val Acc: 62.33%
# Epoch 10/10, Train Loss: 0.6593, Train Acc: 64.29%, Val Loss: 0.6501, Val Acc: 66.33%
# Training with Activation: leaky_relu, Weight Init: xavier, Optimizer: rmsprop
# Epoch 1/10, Train Loss: 16.7865, Train Acc: 56.83%, Val Loss: 0.6739, Val Acc: 60.67%
# Epoch 2/10, Train Loss: 0.7207, Train Acc: 60.67%, Val Loss: 0.6570, Val Acc: 63.83%
# Epoch 3/10, Train Loss: 0.7171, Train Acc: 62.33%, Val Loss: 0.6483, Val Acc: 66.33%
# Epoch 4/10, Train Loss: 0.6961, Train Acc: 63.62%, Val Loss: 0.6737, Val Acc: 66.17%
# Epoch 5/10, Train Loss: 0.7250, Train Acc: 63.00%, Val Loss: 0.6517, Val Acc: 66.17%
# Epoch 6/10, Train Loss: 0.8143, Train Acc: 60.96%, Val Loss: 0.6564, Val Acc: 65.67%
# Epoch 7/10, Train Loss: 0.8396, Train Acc: 60.29%, Val Loss: 0.6733, Val Acc: 66.33%
# Epoch 8/10, Train Loss: 0.7968, Train Acc: 61.96%, Val Loss: 0.6554, Val Acc: 65.50%
# Epoch 9/10, Train Loss: 0.7368, Train Acc: 61.42%, Val Loss: 0.6629, Val Acc: 65.67%
# Epoch 10/10, Train Loss: 0.7667, Train Acc: 62.46%, Val Loss: 0.6668, Val Acc: 62.00%
# Training with Activation: leaky_relu, Weight Init: kaiming, Optimizer: sgd
# Epoch 1/10, Train Loss: 0.8800, Train Acc: 58.79%, Val Loss: 0.6632, Val Acc: 63.67%
# Epoch 2/10, Train Loss: 0.6315, Train Acc: 66.08%, Val Loss: 0.6550, Val Acc: 65.83%
# Epoch 3/10, Train Loss: 0.6138, Train Acc: 66.71%, Val Loss: 0.6632, Val Acc: 66.17%
# Epoch 4/10, Train Loss: 0.5923, Train Acc: 69.92%, Val Loss: 0.6679, Val Acc: 65.17%
# Epoch 5/10, Train Loss: 0.5712, Train Acc: 70.46%, Val Loss: 0.6809, Val Acc: 65.67%
# Epoch 6/10, Train Loss: 0.5518, Train Acc: 72.58%, Val Loss: 0.7159, Val Acc: 66.33%
# Epoch 7/10, Train Loss: 0.5240, Train Acc: 74.42%, Val Loss: 0.7071, Val Acc: 59.67%
# Epoch 8/10, Train Loss: 0.4870, Train Acc: 77.00%, Val Loss: 0.7834, Val Acc: 65.83%
# Epoch 9/10, Train Loss: 0.4500, Train Acc: 80.12%, Val Loss: 0.7396, Val Acc: 59.17%
# Epoch 10/10, Train Loss: 0.4103, Train Acc: 82.38%, Val Loss: 0.7593, Val Acc: 57.50%
# Training with Activation: leaky_relu, Weight Init: kaiming, Optimizer: adam
# Epoch 1/10, Train Loss: 3.5990, Train Acc: 57.21%, Val Loss: 0.6534, Val Acc: 66.33%
# Epoch 2/10, Train Loss: 0.6877, Train Acc: 62.62%, Val Loss: 0.6883, Val Acc: 63.00%
# Epoch 3/10, Train Loss: 0.6843, Train Acc: 62.96%, Val Loss: 0.6431, Val Acc: 66.33%
# Epoch 4/10, Train Loss: 0.6739, Train Acc: 64.38%, Val Loss: 0.6432, Val Acc: 66.33%
# Epoch 5/10, Train Loss: 0.6765, Train Acc: 63.04%, Val Loss: 0.6717, Val Acc: 63.33%
# Epoch 6/10, Train Loss: 0.6629, Train Acc: 64.12%, Val Loss: 0.6481, Val Acc: 66.00%
# Epoch 7/10, Train Loss: 0.6559, Train Acc: 64.33%, Val Loss: 0.6544, Val Acc: 66.33%
# Epoch 8/10, Train Loss: 0.6593, Train Acc: 63.92%, Val Loss: 0.6542, Val Acc: 65.00%
# Epoch 9/10, Train Loss: 0.6478, Train Acc: 64.83%, Val Loss: 0.6649, Val Acc: 66.33%
# Epoch 10/10, Train Loss: 0.6445, Train Acc: 65.67%, Val Loss: 0.6509, Val Acc: 66.33%
# Training with Activation: leaky_relu, Weight Init: kaiming, Optimizer: rmsprop
# Epoch 1/10, Train Loss: 22.0364, Train Acc: 53.25%, Val Loss: 0.7022, Val Acc: 62.67%
# Epoch 2/10, Train Loss: 0.7564, Train Acc: 61.04%, Val Loss: 0.7364, Val Acc: 66.33%
# Epoch 3/10, Train Loss: 0.7217, Train Acc: 61.29%, Val Loss: 0.6864, Val Acc: 66.33%
# Epoch 4/10, Train Loss: 0.7571, Train Acc: 63.17%, Val Loss: 0.6840, Val Acc: 66.33%
# Epoch 5/10, Train Loss: 0.7220, Train Acc: 62.75%, Val Loss: 0.7766, Val Acc: 66.33%
# Epoch 6/10, Train Loss: 0.7185, Train Acc: 62.12%, Val Loss: 0.6574, Val Acc: 66.00%
# Epoch 7/10, Train Loss: 0.8096, Train Acc: 60.88%, Val Loss: 0.9974, Val Acc: 64.50%
# Epoch 8/10, Train Loss: 0.7552, Train Acc: 62.71%, Val Loss: 0.6699, Val Acc: 60.83%
# Epoch 9/10, Train Loss: 0.8464, Train Acc: 61.00%, Val Loss: 0.7472, Val Acc: 66.17%
# Epoch 10/10, Train Loss: 0.7468, Train Acc: 63.17%, Val Loss: 0.7970, Val Acc: 66.33%
# Training with Activation: leaky_relu, Weight Init: random, Optimizer: sgd
# Epoch 1/10, Train Loss: 0.6674, Train Acc: 64.88%, Val Loss: 0.6544, Val Acc: 66.33%
# Epoch 2/10, Train Loss: 0.6358, Train Acc: 66.50%, Val Loss: 0.6505, Val Acc: 66.33%
# Epoch 3/10, Train Loss: 0.6341, Train Acc: 66.29%, Val Loss: 0.6495, Val Acc: 66.33%
# Epoch 4/10, Train Loss: 0.6288, Train Acc: 66.50%, Val Loss: 0.6705, Val Acc: 66.33%
# Epoch 5/10, Train Loss: 0.6215, Train Acc: 66.75%, Val Loss: 0.6537, Val Acc: 66.17%
# Epoch 6/10, Train Loss: 0.6153, Train Acc: 67.46%, Val Loss: 0.6584, Val Acc: 66.17%
# Epoch 7/10, Train Loss: 0.6018, Train Acc: 68.29%, Val Loss: 0.6697, Val Acc: 61.17%
# Epoch 8/10, Train Loss: 0.5863, Train Acc: 68.79%, Val Loss: 0.6964, Val Acc: 58.50%
# Epoch 9/10, Train Loss: 0.5845, Train Acc: 68.38%, Val Loss: 0.6798, Val Acc: 64.50%
# Epoch 10/10, Train Loss: 0.5582, Train Acc: 71.42%, Val Loss: 0.7074, Val Acc: 65.00%
# Training with Activation: leaky_relu, Weight Init: random, Optimizer: adam
# Epoch 1/10, Train Loss: 0.8590, Train Acc: 62.54%, Val Loss: 0.6480, Val Acc: 66.33%
# Epoch 2/10, Train Loss: 0.6497, Train Acc: 65.83%, Val Loss: 0.6466, Val Acc: 66.00%
# Epoch 3/10, Train Loss: 0.6460, Train Acc: 66.17%, Val Loss: 0.6459, Val Acc: 66.33%
# Epoch 4/10, Train Loss: 0.6469, Train Acc: 66.21%, Val Loss: 0.6450, Val Acc: 66.33%
# Epoch 5/10, Train Loss: 0.6435, Train Acc: 65.50%, Val Loss: 0.6412, Val Acc: 66.33%
# Epoch 6/10, Train Loss: 0.6475, Train Acc: 65.96%, Val Loss: 0.6457, Val Acc: 66.33%
# Epoch 7/10, Train Loss: 0.6490, Train Acc: 65.71%, Val Loss: 0.6563, Val Acc: 66.33%
# Epoch 8/10, Train Loss: 0.6463, Train Acc: 66.33%, Val Loss: 0.6625, Val Acc: 66.33%
# Epoch 9/10, Train Loss: 0.6534, Train Acc: 65.25%, Val Loss: 0.6441, Val Acc: 66.33%
# Epoch 10/10, Train Loss: 0.6511, Train Acc: 65.88%, Val Loss: 0.6494, Val Acc: 66.50%
# Training with Activation: leaky_relu, Weight Init: random, Optimizer: rmsprop
# Epoch 1/10, Train Loss: 5.5796, Train Acc: 57.21%, Val Loss: 0.6430, Val Acc: 66.50%
# Epoch 2/10, Train Loss: 0.6584, Train Acc: 65.71%, Val Loss: 0.6461, Val Acc: 66.33%
# Epoch 3/10, Train Loss: 0.6602, Train Acc: 66.12%, Val Loss: 0.6452, Val Acc: 66.33%
# Epoch 4/10, Train Loss: 0.6969, Train Acc: 64.88%, Val Loss: 0.6497, Val Acc: 66.33%
# Epoch 5/10, Train Loss: 0.6959, Train Acc: 64.29%, Val Loss: 0.6492, Val Acc: 66.33%
# Epoch 6/10, Train Loss: 0.6618, Train Acc: 66.33%, Val Loss: 0.6452, Val Acc: 66.33%
# Epoch 7/10, Train Loss: 0.6941, Train Acc: 64.12%, Val Loss: 0.6772, Val Acc: 66.33%
# Epoch 8/10, Train Loss: 0.7100, Train Acc: 64.33%, Val Loss: 0.6565, Val Acc: 66.33%
# Epoch 9/10, Train Loss: 0.6940, Train Acc: 64.17%, Val Loss: 0.6986, Val Acc: 66.33%
# Epoch 10/10, Train Loss: 0.7703, Train Acc: 63.42%, Val Loss: 0.6597, Val Acc: 66.33%

# %%
# Load pretrained ResNet-18 model
resnet18 = models.resnet18(pretrained=True)

# Modify the final layer for Cats vs. Dogs (2 classes)
resnet18.fc = nn.Linear(resnet18.fc.in_features, 2)

# Define optimizer and loss function
optimizer_resnet = optim.Adam(resnet18.parameters(), lr=0.001)
criterion_resnet = nn.CrossEntropyLoss()

# Train ResNet-18
train_losses_resnet, val_losses_resnet, train_accuracies_resnet, val_accuracies_resnet = train_model(resnet18, train_loader, val_loader, optimizer_resnet, criterion_resnet, num_epochs=10)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 53.9MB/s]
# Epoch 1/10, Train Loss: 0.8764, Train Acc: 61.50%, Val Loss: 0.6408, Val Acc: 66.50%
# Epoch 2/10, Train Loss: 0.6890, Train Acc: 66.38%, Val Loss: 0.6501, Val Acc: 65.50%
# Epoch 3/10, Train Loss: 0.6513, Train Acc: 66.04%, Val Loss: 0.6688, Val Acc: 66.33%
# Epoch 4/10, Train Loss: 0.6492, Train Acc: 66.00%, Val Loss: 0.6663, Val Acc: 64.67%
# Epoch 5/10, Train Loss: 0.6189, Train Acc: 67.42%, Val Loss: 0.7170, Val Acc: 65.17%
# Epoch 6/10, Train Loss: 0.5813, Train Acc: 70.38%, Val Loss: 0.7056, Val Acc: 64.00%
# Epoch 7/10, Train Loss: 0.5783, Train Acc: 69.83%, Val Loss: 0.7416, Val Acc: 64.83%
# Epoch 8/10, Train Loss: 0.5462, Train Acc: 73.33%, Val Loss: 1.0364, Val Acc: 60.33%
# Epoch 9/10, Train Loss: 0.4784, Train Acc: 78.50%, Val Loss: 0.7720, Val Acc: 61.33%
# Epoch 10/10, Train Loss: 0.3885, Train Acc: 83.04%, Val Loss: 0.9647, Val Acc: 54.17%

# %%
# Save the best model weights
torch.save(model.state_dict(), 'best_model_cats_vs_dogs.pth')
torch.save(resnet18.state_dict(), 'best_resnet18_cats_vs_dogs.pth')

# %%
# Plot training and validation loss
plt.figure(figsize=(12, 6))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.figure(figsize=(12, 6))
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
# Modify the final layer for CIFAR-10 (10 classes)
model.fc2 = nn.Linear(512, 10)
